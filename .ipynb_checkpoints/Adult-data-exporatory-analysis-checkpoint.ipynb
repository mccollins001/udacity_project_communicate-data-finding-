# %% [markdown]
# # <center>Part I - Exploratory Analysis of Adult Income Dataset</center>
# ### <center>by</center>
#
# ## <center>Chukwudi Collins Ozoede</center>
#
# ## Introduction
# > The US Adult income dataset is a repository of 48,842 entries extracted from the 1994 US Census database.
# It contains 15 columns before cleaning. Below are the columns and their meaning:
#
# ### The Dataset
# - **age:** the age of an individual
# - **workclass:** a general term to represent the employment status of an individual
# - **fnlwgt:** final weight. In other words, this is the number of people the census believesthe entry represents..
# - **education:** the highest level of education achieved by an individual.
# - **education-num:** the highest level of education achieved in numerical form.
# - **marital-status:** marital status of an individual.
# - **occupation:** the general type of occupation of an individual
# - **relationship:** represents what this individual is relative to others.
# - **race:** Descriptions of an individual’s race
# - **sex:** the biological sex of the individual
# - **capital-gain:** capital gains for an individual
# - **capital-loss:** capital loss for an individual
# - **hours-per-week**: the hours an individual has reported to work per week
# - **native-country:** country of origin for an individual
# - **Salary:** whether or not an individual makes more than $50,000 annually.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# %% [markdown]
# > Load in your dataset and describe its properties through the questions below. Try and motivate your exploration goals through this section.

# %%
adult_df = pd.read_csv('adult.data.csv')
adult_df.sample(50)
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 1100    68                 ?  140282       7th-8th              4
# 17168   63                 ?   64448       HS-grad              9
# 18566   64       Federal-gov   86837    Assoc-acdm             12
# 3633    76           Private  316185       7th-8th              4
# 4378    45           Private  178215           9th              5
# 25874   38  Self-emp-not-inc  342635     Bachelors             13
# 29875   18           Private   45316          11th              7
# 23404   47      Self-emp-inc  350759       HS-grad              9
# 6576    39           Private  211440     Bachelors             13
# 536     57           Private  190942       1st-4th              2
# 12487   34           Private  119153          11th              7
# 24370   62           Private  132917  Some-college             10
# 11325   50  Self-emp-not-inc  312477       HS-grad              9
# 28320   36                 ?  504871       HS-grad              9
# 29263   41      Self-emp-inc  230168  Some-college             10
# 11129   27           Private  244566          10th              6
# 14667   34           Private   97306     Bachelors             13
# 2327    25                 ?   41107     Bachelors             13
# 8705    32         Local-gov  296466       Masters             14
# 17291   42  Self-emp-not-inc   30759       HS-grad              9
# 138     20           Private   34310  Some-college             10
# 27213   44           Private  131650    Assoc-acdm             12
# 24179   24         Local-gov  126613     Bachelors             13
# 5865    24           Private  190293     Bachelors             13
# 17492   26           Private  250038  Some-college             10
# 24164   42      Self-emp-inc  277488   Prof-school             15
# 19291   50  Self-emp-not-inc  341797   Prof-school             15
# 14635   27         State-gov  280618       Masters             14
# 27506   44           Private   43711     Bachelors             13
# 19483   53           Private   95469     Bachelors             13
# 20979   28           Private  123147  Some-college             10
# 2357    47           Private  481987       HS-grad              9
# 32214   22         Local-gov  164775       5th-6th              3
# 15376   55  Self-emp-not-inc  145574       HS-grad              9
# 25005   19           Private  228939       HS-grad              9
# 26871   53           Private   48343       HS-grad              9
# 4805    51       Federal-gov  282680     Doctorate             16
# 26250   36  Self-emp-not-inc  257250     Assoc-voc             11
# 6260    42           Private  341204       HS-grad              9
# 30280   25           Private  169124       HS-grad              9
# 29205   23           Private  314894       HS-grad              9
# 18768   34         Local-gov  143766  Some-college             10
# 9712    30                 ?  157289          11th              7
# 21202   22           Private  183083  Some-college             10
# 28238   32           Private  205581  Some-college             10
# 1733    35           Private  239755     Bachelors             13
# 2814    27           Private  214858     Bachelors             13
# 18981   25           Private  323139     Bachelors             13
# 31607   26           Private  211695     Bachelors             13
# 20171   25           Private   71351       1st-4th              2
#
#               marital-status         occupation    relationship  \
# 1100      Married-civ-spouse                  ?         Husband
# 17168     Married-civ-spouse                  ?         Husband
# 18566     Married-civ-spouse      Other-service         Husband
# 3633                 Widowed    Protective-serv   Not-in-family
# 4378      Married-civ-spouse  Machine-op-inspct            Wife
# 25874     Married-civ-spouse     Prof-specialty         Husband
# 29875          Never-married      Other-service       Own-child
# 23404     Married-civ-spouse    Exec-managerial         Husband
# 6576      Married-civ-spouse              Sales         Husband
# 536                  Widowed    Priv-house-serv   Not-in-family
# 12487     Married-civ-spouse   Transport-moving         Husband
# 24370     Married-civ-spouse   Transport-moving         Husband
# 11325     Married-civ-spouse    Exec-managerial         Husband
# 28320     Married-civ-spouse                  ?         Husband
# 29263     Married-civ-spouse              Sales         Husband
# 11129     Married-civ-spouse  Handlers-cleaners         Husband
# 14667               Divorced       Craft-repair       Unmarried
# 2327   Married-spouse-absent                  ?   Not-in-family
# 8705           Never-married     Prof-specialty   Not-in-family
# 17291     Married-civ-spouse       Craft-repair         Husband
# 138            Never-married              Sales       Own-child
# 27213     Married-civ-spouse    Exec-managerial         Husband
# 24179          Never-married     Prof-specialty       Own-child
# 5865           Never-married     Prof-specialty   Not-in-family
# 17492     Married-civ-spouse       Adm-clerical         Husband
# 24164     Married-civ-spouse     Prof-specialty         Husband
# 19291     Married-civ-spouse     Prof-specialty         Husband
# 14635          Never-married     Prof-specialty   Not-in-family
# 27506          Never-married      Other-service   Not-in-family
# 19483     Married-civ-spouse       Adm-clerical         Husband
# 20979          Never-married       Tech-support   Not-in-family
# 2357      Married-civ-spouse      Other-service         Husband
# 32214          Never-married  Handlers-cleaners  Other-relative
# 15376               Divorced    Exec-managerial   Not-in-family
# 25005          Never-married  Handlers-cleaners       Own-child
# 26871     Married-civ-spouse   Transport-moving         Husband
# 4805           Never-married     Prof-specialty   Not-in-family
# 26250     Married-civ-spouse    Farming-fishing         Husband
# 6260                Divorced       Craft-repair  Other-relative
# 30280     Married-civ-spouse   Transport-moving         Husband
# 29205          Never-married    Exec-managerial       Own-child
# 18768          Never-married    Protective-serv       Own-child
# 9712           Never-married                  ?       Unmarried
# 21202          Never-married  Machine-op-inspct   Not-in-family
# 28238              Separated       Tech-support       Unmarried
# 1733           Never-married      Other-service   Not-in-family
# 2814           Never-married              Sales       Own-child
# 18981          Never-married  Handlers-cleaners       Own-child
# 31607          Never-married     Prof-specialty       Own-child
# 20171          Never-married      Other-service  Other-relative
#
#                      race     sex  capital-gain  capital-loss  hours-per-week  \
# 1100                White    Male             0             0               8
# 17168               White    Male             0             0              40
# 18566  Asian-Pac-Islander    Male             0             0              40
# 3633                White  Female             0             0              12
# 4378                White  Female             0             0              40
# 25874               White    Male             0             0              70
# 29875               White  Female             0             0              20
# 23404               White    Male             0             0              40
# 6576                White    Male             0             0              50
# 536                 Black  Female             0             0              30
# 12487               White    Male             0             0              50
# 24370               Black    Male             0             0              20
# 11325               White    Male             0          1887              40
# 28320               White    Male             0             0              40
# 29263               White    Male             0             0              91
# 11129               White    Male             0             0              40
# 14667               White  Female             0             0              25
# 2327                White    Male             0             0              40
# 8705                White    Male             0             0              60
# 17291               White    Male             0             0              35
# 138                 White    Male             0             0              20
# 27213               White    Male             0             0              54
# 24179               White  Female             0             0              20
# 5865                White  Female             0             0              40
# 17492               White    Male             0             0              40
# 24164               White    Male         15024             0              65
# 19291               White    Male             0             0              50
# 14635               White    Male             0             0              40
# 27506               White    Male             0             0              48
# 19483               White    Male             0          1902              40
# 20979               White  Female          4865             0              40
# 2357                White    Male             0             0              40
# 32214               White    Male             0             0              40
# 15376               White    Male         34095             0              60
# 25005               White    Male             0             0              35
# 26871               White    Male             0          1902              40
# 4805                White  Female             0          1564              70
# 26250               White    Male             0             0              99
# 6260                White  Female             0             0              40
# 30280               White    Male             0             0              45
# 29205               White  Female             0             0              45
# 18768               White    Male             0             0              40
# 9712                White    Male             0             0              40
# 21202               White  Female             0             0              35
# 28238               White  Female             0             0              50
# 1733                White    Male             0             0              38
# 2814                White    Male             0             0              40
# 18981               White    Male             0             0              35
# 31607               White    Male             0             0              40
# 20171               White    Male             0             0              25
#
#       native-country salary
# 1100   United-States  <=50K
# 17168  United-States  <=50K
# 18566  United-States   >50K
# 3633   United-States  <=50K
# 4378   United-States   >50K
# 25874  United-States  <=50K
# 29875  United-States  <=50K
# 23404  United-States   >50K
# 6576   United-States   >50K
# 536    United-States  <=50K
# 12487  United-States  <=50K
# 24370  United-States  <=50K
# 11325  United-States   >50K
# 28320  United-States   >50K
# 29263  United-States  <=50K
# 11129  United-States  <=50K
# 14667  United-States  <=50K
# 2327          Canada  <=50K
# 8705   United-States  <=50K
# 17291  United-States  <=50K
# 138    United-States  <=50K
# 27213  United-States   >50K
# 24179  United-States  <=50K
# 5865   United-States  <=50K
# 17492  United-States   >50K
# 24164  United-States   >50K
# 19291  United-States   >50K
# 14635  United-States  <=50K
# 27506  United-States  <=50K
# 19483  United-States   >50K
# 20979  United-States  <=50K
# 2357   United-States   >50K
# 32214      Guatemala   >50K
# 15376  United-States  <=50K
# 25005  United-States  <=50K
# 26871  United-States   >50K
# 4805   United-States   >50K
# 26250  United-States  <=50K
# 6260   United-States  <=50K
# 30280  United-States  <=50K
# 29205  United-States  <=50K
# 18768  United-States  <=50K
# 9712   United-States  <=50K
# 21202  United-States  <=50K
# 28238  United-States  <=50K
# 1733   United-States  <=50K
# 2814   United-States  <=50K
# 18981  United-States  <=50K
# 31607  United-States  <=50K
# 20171    El-Salvador  <=50K

# %%
# this is an overview of the data shape and composition
print(adult_df.shape)
print(adult_df.dtypes)
print(adult_df.info())
# Out:
# (32561, 15)
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# salary            object
# dtype: object
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
# None

# %%
# making a copy of the dataframe before cleaning and analysis
df = adult_df.copy()

# %% [markdown]
# ### Data cleaning
# - Unnecessary columns have to be removed from the dataset
# - I discovered that some cells have '?' as their values, they should all be changed to NAN
# - I need to create a new column `age_group` to store age groups

# %% [markdown]
# #### Issue 1:
# Removing unnecessary columns from the dataframe

# %%
# subseting for the columns needed for this ananlysis
df = df[['age','workclass','education','marital-status', 'occupation', 'relationship', 
         'race', 'sex', 'hours-per-week', 'native-country','salary']]
df.head(1)
# Out:
#    age  workclass  education marital-status    occupation   relationship  \
# 0   39  State-gov  Bachelors  Never-married  Adm-clerical  Not-in-family
#
#     race   sex  hours-per-week native-country salary
# 0  White  Male              40  United-States  <=50K

# %% [markdown]
# #### Issue 2:
# changing '?' values to NAN

# %%
#solution:
df = df.replace('?', np.nan)
df.head(5)
# Out:
#    age         workclass  education      marital-status         occupation  \
# 0   39         State-gov  Bachelors       Never-married       Adm-clerical
# 1   50  Self-emp-not-inc  Bachelors  Married-civ-spouse    Exec-managerial
# 2   38           Private    HS-grad            Divorced  Handlers-cleaners
# 3   53           Private       11th  Married-civ-spouse  Handlers-cleaners
# 4   28           Private  Bachelors  Married-civ-spouse     Prof-specialty
#
#     relationship   race     sex  hours-per-week native-country salary
# 0  Not-in-family  White    Male              40  United-States  <=50K
# 1        Husband  White    Male              13  United-States  <=50K
# 2  Not-in-family  White    Male              40  United-States  <=50K
# 3        Husband  Black    Male              40  United-States  <=50K
# 4           Wife  Black  Female              40           Cuba  <=50K

# %% [markdown]
# #### Issue 3:
# Create new column `age_group`

# %%
#create an age group to avoid noisy and clustered visuals 
ages = df.age
age_group = []
for i, age in ages.items():
    
    if age <= 20:
        age_group.append('17-20')
    elif age>20 and age<31:
        age_group.append('21-30')
    elif age>30 and age<41:
        age_group.append('31-40')
    elif age>40 and age<51:
        age_group.append('41-50')
    elif age>50 and age<61:
        age_group.append('51-60')
    elif age>60 and age<71:
        age_group.append('61-70')
    elif age>70 and age<81:
        age_group.append('71-80')
    else:
        age_group.append('above 80')
df['age_group']= age_group


# this method can also be used
"""
conditions = [
    (df['age']<=20),
    (df['age']>20) & (df['age']<31),
    (df['age']>30) & (df['age']<41),
    (df['age']>40) & (df['age']<51),
    (df['age']>50) & (df['age']<61),
    (df['age']>60) & (df['age']<71),
    (df['age']>70) & (df['age']<81),
    (df['age']>80),
    ]

# create a list of the values we want to assign for each condition
values = ['17-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', 'above 80']

# create a new column and use np.select to assign values to it using our lists as arguments
df['age_group'] = np.select(conditions, values)



# display updated DataFrame
df.head()
"""
# Out:
# "\nconditions = [\n    (df['age']<=20),\n    (df['age']>20) & (df['age']<31),\n    (df['age']>30) & (df['age']<41),\n    (df['age']>40) & (df['age']<51),\n    (df['age']>50) & (df['age']<61),\n    (df['age']>60) & (df['age']<71),\n    (df['age']>70) & (df['age']<81),\n    (df['age']>80),\n    ]\n\n# create a list of the values we want to assign for each condition\nvalues = ['17-20', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', 'above 80']\n\n# create a new column and use np.select to assign values to it using our lists as arguments\ndf['age_group'] = np.select(conditions, values)\n\n\n\n# display updated DataFrame\ndf.head()\n"

# %% [markdown]
# ### What is the structure of your dataset?
#
# > My dataset contains 32561 rows and 16 columns, It contains no null values
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > The main porpose of this analysis is to find the distribution of salary in the US and how it is affected by different factors such as age, race, education etc.
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# >What my investigation is looking for is how different factors (columns) such as education, marital-status, native country make people make less than 50k usd or more

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, I will investigate distributions of individual variables. If
# I see unusual points or outliers, I will take a deeper look to clean things up
# and prepare myself to look at relationships between variables.

# %% [markdown]
# ### Question 1:
# what percentage of people earn above and below 50k usd

# %% [markdown]
# ### visualization :

# %%
# getting the distribution by salary group
sal_dist= df['salary'].value_counts().reset_index()
(list(sal_dist['index']))
# Out:
# ['<=50K', '>50K']

# %%
#plotting a pie since we only have 2 variables

#creating a function for the pie
def pie_1(data, title, explode,legend, fig_x =6, fig_y=6, shadow = False, startangle =90,autopct ='%1.1f%%'):
    plt.figure(figsize=[fig_x, fig_y])
    
    plt.pie(data, explode = explode, autopct=autopct ,shadow=shadow, startangle=startangle)
    plt.title(title)
    plt.legend(legend)
    
#calling the function    
pie_1(list(sal_dist['salary']),title = 'salary distribution' ,fig_x =6, fig_y=6, 
      explode =[0.1,0], shadow = True, legend = (list(sal_dist['index'])));

# %% [markdown]
# ### observations:
# I can observe that about 76% of the people earn 50k and below while 24% earn above 50k

# %% [markdown]
# ### Question 2:
# Which race do these people belong to

# %% [markdown]
# ### Visualization:

# %%
# grouping by race
top_10 = df['race'].value_counts()
top_10
# Out:
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: race, dtype: int64

# %%
#plotting a horizontal barchart
plt.barh(top_10.index, top_10.values, alpha=0.7)
plt.title('Race distribution chart');

# %% [markdown]
# ### obsevation:
# White people are by far more represented in the dataset, a distant second is black people

# %% [markdown]
# ### Question 3:
# For how long do people work in a week?

# %% [markdown]
# ### Visualization:

# %%
hours = df['hours-per-week'].value_counts()
hours.head(4)
# Out:
# 40    15217
# 50     2819
# 45     1824
# 60     1475
# Name: hours-per-week, dtype: int64

# %%
def hist_1(df_i, col, x_label, y_label, title, sub_x=1, sub_y=2, sub_z=1, fig_x =6, fig_y=15, alpha = 0, start_bins = 0.0):
    plt.figure(figsize=[fig_x, fig_y])
    plt.subplot(sub_x, sub_y, sub_z)
    
    bins = np.arange(start_bins, df[col].max()+5.5, 5)
    plt.hist(data = df_i, x = col, bins=bins, alpha = alpha)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    
hist_1(df_i=df, col='hours-per-week', x_label = 'hours', y_label = 'population', title = 'distribution by weekly work hour', 
       alpha = 0.7, start_bins = 03.0,fig_x=10, fig_y=10,sub_x=2, sub_y=1, sub_z=1)

# %% [markdown]
# ### obsevation:
# Most people work the standard 40hrs per week (15,000 people), about 3000 people work 50 hrs every week

# %% [markdown]
# ### Question 4 :
# What is the distribution of education level

# %% [markdown]
# ### Visualization:

# %%
edu = df['education'].value_counts()
edu
# Out:
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
#plotting a horizontal barchart
plt.figure(figsize = [12,6])
plt.barh(edu.index, edu.values, alpha=0.7)
plt.title('Education level distribution chart')
plt.xlabel('population');

# %% [markdown]
# ### obsevation:
# majority of them have either a some-college, high school or bachelors degree certificates, very few have preschool

# %% [markdown]
# ### Question 5:
# What is the age distribution amongst the people?

# %% [markdown]
# ### Visualization:

# %%
ages = df['age'].value_counts()
ages.head(2)
# Out:
# 36    898
# 31    888
# Name: age, dtype: int64

# %%
ages1 = df.age_group.value_counts().sort_values(ascending =False)
ages1
# Out:
# 31-40       8546
# 21-30       8162
# 41-50       6983
# 51-60       4128
# 17-20       2410
# 61-70       1792
# 71-80        441
# above 80      99
# Name: age_group, dtype: int64

# %%
hist_1(df_i=df, col='age', x_label = 'age group', y_label = 'population', title = 'Age', 
       alpha = 1,fig_x=16, fig_y=6, sub_x=1, sub_y=2, sub_z=1)

plt.subplot(1,2,2)
base_color = sb.color_palette()[0]
sb.barplot( ages1.index, ages1.values, color= base_color)
plt.xlabel('Age group')
plt.title('Age group distribution');
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### obsevation:
# The  age distribution is right skewed and the most frequent age group falls between 21 and 50 years

# %% [markdown]
# ### Question 6:
# What is the population distribution by country of origin

# %% [markdown]
# ### Visualization:

# %%
country = df['native-country'].value_counts()
country
# Out:
# United-States                 29170
# Mexico                          643
# Philippines                     198
# Germany                         137
# Canada                          121
# Puerto-Rico                     114
# El-Salvador                     106
# India                           100
# Cuba                             95
# England                          90
# Jamaica                          81
# South                            80
# China                            75
# Italy                            73
# Dominican-Republic               70
# Vietnam                          67
# Guatemala                        64
# Japan                            62
# Poland                           60
# Columbia                         59
# Taiwan                           51
# Haiti                            44
# Iran                             43
# Portugal                         37
# Nicaragua                        34
# Peru                             31
# France                           29
# Greece                           29
# Ecuador                          28
# Ireland                          24
# Hong                             20
# Trinadad&Tobago                  19
# Cambodia                         19
# Thailand                         18
# Laos                             18
# Yugoslavia                       16
# Outlying-US(Guam-USVI-etc)       14
# Honduras                         13
# Hungary                          13
# Scotland                         12
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
US = country.values[0]
others= country.values[1:].sum()

# %%
#define size of figure
plt.figure(figsize=[20,15])

#subplots
plt.subplot(2,2,1)
plt.barh(country.index[:10],country.values[:10])
plt.title('Top 10 countries')
plt.xlabel('population')

plt.subplot(2,2,2)
plt.barh(country.index[1:11],country.values[1:11])
plt.title('Top 10 countries without the US')
plt.xlabel('population');

plt.subplot(2,2,3)
plt.barh(country.index[-10:],country.values[-10:])
plt.title('Bottom 10 countries')
plt.xlabel('population');

plt.subplot(2,2,4)
explode = [0.1, 0]
label = ['US','others']
#fig = plt.figure(figsize =(6, 6))
plt.pie([US,others], labels = label, explode = explode, autopct='%1.1f%%',shadow=True, startangle=90, colors = ( "#BADC58", "#22A6B3")) 
plt.title('percentage distribution of salary groups between the US and others' )
plt.axis('equal');

# %% [markdown]
# ### obsevation:

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# I am mostly interested in the `salary` distribution, We can observe that about 76% of the people earn 50k and below while only 24% earn above 50k. We shall analyze further to unravel the factors that affect `salary`
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# No, the distribution is normal and there are no outliers

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, I shall investigate relationships between pairs of variables in
# data.I will Make sure the variables that I cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Question 7:
# What is the relationship between age and salary

# %% [markdown]
# ### Visualization:

# %%
plt.figure(figsize=[8,5])
base_color = sb.color_palette()[0]
sb.violinplot(data=df,x='salary', y ='age', color=base_color, inner =None)
plt.title('Salary by age distribution')
plt.xlabel('Salary group');

# %% [markdown]
# ### obsevation:
# I can observe that people between 20 and 30 are more likely to earn 50k and below, while people between 31 and 60 are more likely to earn above 50k

# %% [markdown]
# ### Question 8:
# How does gender affect salary?

# %% [markdown]
# ### Visualization:

# %%
plt.figure(figsize= [6,5])
sb.countplot(data = df, x = 'salary', hue = 'sex')
plt.title('Salary by gender');

# %% [markdown]
# ### obsevation:
# - There are more male folks in the Dataset.
# - Secondly, male folks are more likely to earn above 50k than the female folk

# %% [markdown]
# ### Question 9 - 11:
# How do `education`, `age_group` and `race` affect `salary`?

# %% [markdown]
# ### Visualization:

# %%
plt.figure(figsize =[20,12])

plt.subplot(2,2,1)
sb.countplot(data=df, y='education', hue='salary')
plt.title('Salary by education')
plt.xlabel('population')

plt.subplot(2,2,3)
sb.countplot(data = df, y = 'age_group', hue = 'salary')
plt.title('salary by age group')
plt.xlabel('population')

plt.subplot(2,2,4)
sb.countplot(data = df, y = 'race', hue = 'salary')
plt.title('Salary by race')
plt.xlabel('population')

plt.subplot(2,2,2)
sb.countplot(data = df, y = 'education', hue = 'salary')
plt.xlim(0,2000)
plt.title('Salary by education zoomed in to 2000 people')
plt.xlabel('population');

# %% [markdown]
# ### obsevation:
# - people who have a `Bachelors`, `Masters`, `Doctorate` degrees and professors have high `>50k` / `>=50` ratio
# - There are more white folks in the Dataset. Secondly, white folks are more likely to earn above 50k than other races.
# - people above 31 and below 71 are more likely to earn above 50k however, people above 60 years are few in the dataset

# %% [markdown]
# ### Question 12:
# How does `relationship` affect `salary`

# %% [markdown]
# ### Visualization:

# %%
sb.countplot(data=df, y='relationship', hue='salary',palette='viridis')
plt.title('Salary by relationship');

# %% [markdown]
# ### obsevation:
# I observed that married people are more likely to earn high wages than other groups

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?

# %% [markdown]
# I discovered that these people are more likely to earn high salary:
# - People that have a degree
# - white people
# - married people
# - people over 35 and below 50
# - people who are men etc.
#
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# No, there is no relationship
